# %% [markdown]
# # Imbalanced Dataset
# - ### A dataset with unequal class distribution

# %%
import numpy as np
import pandas as pd

# %%
credit_card_df = pd.read_csv('credit_data.csv')
credit_card_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
credit_card_df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# distribution of the two classes [0->legit, 1->fraud]
credit_card_df.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# Highly imbalanced dataset

# %%
legit_transactions = credit_card_df[credit_card_df.Class == 0]
fraudulent_transactions = credit_card_df[credit_card_df.Class == 1]

# %%
legit_transactions.shape, fraudulent_transactions.shape
# Out:
# ((284315, 31), (492, 31))

# %% [markdown]
# ### Undersampling
# Build a sample dataset containing similar distribution of Legit and Fraudulent transactions

# %%
legit_sample = legit_transactions.sample(n=492) # 492 random records
legit_sample.shape
# Out:
# (492, 31)

# %% [markdown]
# Concatenate the two dataframes

# %%
new_df = pd.concat([legit_sample, fraudulent_transactions], axis=0) # add row wise

# %%
new_df.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 28088    34851.0 -1.134569  1.039712  1.664143 -0.161296  0.297783 -0.706640
# 15463    26849.0 -2.693420  2.337264 -0.303612  2.352796  0.091536 -0.544235
# 170826  120372.0  0.107479  1.272812 -1.934159 -0.466879  1.230858 -1.197636
# 42244    41012.0 -2.241933 -5.287394 -2.147628  2.583820 -1.728497 -0.530352
# 114652   73564.0 -0.775932  1.270756  1.020605  0.144648 -0.293701 -0.765563
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 28088   1.299433 -0.464844  0.132868  ... -0.142123  0.002700 -0.242997
# 15463   1.281668 -0.459579  0.769469  ... -0.403418  0.522401 -0.136038
# 170826  1.165312  0.044588 -0.578391  ...  0.177879  0.492414 -0.099265
# 42244   2.993815 -0.849004 -0.547925  ...  1.110897 -0.865194 -1.755071
# 114652  0.267848  0.493036 -0.532631  ... -0.170273 -0.559881  0.131636
#
#              V24       V25       V26       V27       V28   Amount  Class
# 28088   0.377487  0.363658  0.359169 -0.252751 -0.241202    22.00      0
# 15463   0.515889 -0.678903  0.004672  0.717001  0.307317    56.27      0
# 170826  0.440287 -0.329210  0.527895 -0.091790  0.037436    13.56      0
# 42244   0.509848  0.195926 -0.491947 -0.349761  0.328911  1823.20      0
# 114652  0.336963 -0.262931  0.084620  0.132704  0.031115    10.99      0
#
# [5 rows x 31 columns]

# %%
new_df.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
#              V24       V25       V26       V27       V28  Amount  Class
# 279863 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00      1
# 280143 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76      1
# 280149  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89      1
# 281144 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00      1
# 281674 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53      1
#
# [5 rows x 31 columns]

# %%
new_df.Class.value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64
